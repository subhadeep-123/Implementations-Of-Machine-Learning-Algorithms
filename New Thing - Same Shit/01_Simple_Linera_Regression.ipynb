# %%
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %matplotlib inline
plt.style.use('ggplot')

# %%
file = glob.glob('*.csv')[0]
df = pd.read_csv(file)
print(df.head(5))
print('-----------')
print(df.tail(5))
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# -----------
#     YearsExperience    Salary
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
print(f"Shape of the data - {df.shape}")
# Out:
# Shape of the data - (30, 2)

# %%
# Splitting the dataset into intdependet and dependent variable
x = df.iloc[:,:-1].values
print(x, end=',')
y = df.iloc[:, -1].values
print(y)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]],[ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, 
                                                 y, 
                                                 test_size = 0.2,
                                                 random_state=42)
print("The Shape of The Splitted Varis are")
print(f"X-Train - {X_train.shape}")
print(f"Y-Train - {Y_train.shape}")
print(f"X-Test - {X_test.shape}")
print(f"Y-Test - {Y_test.shape}")
# Out:
# The Shape of The Splitted Varis are
# X-Train - (24, 1)
# Y-Train - (24,)
# X-Test - (6, 1)
# Y-Test - (6,)

# %%
## Making the model
regressor = LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
## Prediction the results
y_pred = regressor.predict(X_test)

# %%
## Plotting the Results
figure = plt.figure(figsize=(6,6))
plt.scatter(X_train,Y_train, color='red')
plt.plot(X_train, regressor.predict(X_train), color='blue')
plt.title('Salary Vs Experience Training')
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.show()

# %%
## Plotting the Results
figure = plt.figure(figsize=(6,5))
plt.scatter(X_test,Y_test, color='red')
plt.plot(X_train, regressor.predict(X_train), color='blue')
plt.title('Salary Vs Experience Test')
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.show()
